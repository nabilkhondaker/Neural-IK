# %% [markdown]
# # Neural IK Lab Notebook
#
# Open this notebook after installing the package:
# ```
# pip install -e ".[notebook]"
# ```

# %%
from neural_ik.robotics.models.planar_2r import Planar2R
robot = Planar2R()
print(robot)
